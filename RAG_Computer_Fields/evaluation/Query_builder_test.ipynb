# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()

sys.path.insert(0, str(PROJECT_ROOT))

from rag.query_builder import QueryBuilder

print("QueryBuilder imported successfully!")
# Out:
# QueryBuilder imported successfully!

# %%
builder = QueryBuilder()

query = builder.build(
    "Explain object detection in computer vision."
)

print("Query:")
print(query)
# Out:
# Query:
# Explain object detection in computer vision.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

from rag.retriever import Retriever

retriever = Retriever()
# Out:
# Loading embedding model...
# ...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# Embedding model loaded!
# Loading FAISS index...
# FAISS index loaded!
# Loading metadata...
# Metadata loaded!
#
# ...
# RETRIEVER INITIALIZED
# ...
# Vectors: 2150
# Metadata: 2150
# Embedding dimension: 384
# ...

# %%
query = "Explain object detection in computer vision."

results = retriever.retrieve(
    query,
    top_k=5
)

print("=" * 80)
print("QUERY:", query)
print("=" * 80)

for i, result in enumerate(results, 1):
    print(f"\n{i}.")
    print("Score:", result["score"])
    print("ID:", result["id"])
    print("Question:", result["metadata"]["question"])
    print("Track:", result["metadata"]["track"])
    print("Category:", result["metadata"]["category"])
# Out:
# ...
# QUERY: Explain object detection in computer vision.
# ...
#
# 1.
# Score: 0.791130006313324
# ID: ai_ml_computer_vision_q021
# Question: What is object detection?
# Track: ai_ml
# Category: computer_vision
#
# 2.
# Score: 0.7546595335006714
# ID: ai_ml_computer_vision_q022
# Question: What is the difference between image classification and object detection?
# Track: ai_ml
# Category: computer_vision
#
# 3.
# Score: 0.7393874526023865
# ID: ai_ml_computer_vision_q028
# Question: What is image segmentation?
# Track: ai_ml
# Category: computer_vision
#
# 4.
# Score: 0.738498330116272
# ID: ai_ml_computer_vision_q041
# Question: What is face detection?
# Track: ai_ml
# Category: computer_vision
#
# 5.
# Score: 0.7383772730827332
# ID: ai_ml_computer_vision_q023
# Question: What is a bounding box in object detection?
# Track: ai_ml
# Category: computer_vision
